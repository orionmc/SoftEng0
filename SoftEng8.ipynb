# %%
import csv
import pandas as pd
import sweetviz as sv
from pycaret.classification import *

# import matplotlib
# matplotlib.use('TkAgg')  # Or 'Qt5Agg', 'Agg', depending on your setup



# # Ignore all warnings
# import warnings
# warnings.filterwarnings("ignore")


# Loading the dataset
# heartds0 = pd.read_csv('https://raw.githubusercontent.com/orionmc/SoftEng0/main/heart.ds.csv')
heartds0 = pd.read_csv(r'C:\Users\user0\Documents\BPP\Software Engineering\Git\0\SoftEng0\SoftEng0\heart.ds.csv')


#report = sv.analyze(heartds0, target_feat='output')
#report.show_notebook()

s = setup(heartds0,                     # data set
          target = 'output',            # the goal for prediction
          ignore_features = ['sex'],    # we may ignore certaion futures if deement irrelevant
          session_id = 123)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[30], line 4
#       2 import pandas as pd
#       3 import sweetviz as sv
# ----> 4 from pycaret.classification import *
#       6 # import matplotlib
#       7 # matplotlib.use('TkAgg')  # Or 'Qt5Agg', 'Agg', depending on your setup
#       8
#    (...)
#      16 # Loading the dataset
#      17 # heartds0 = pd.read_csv('https://raw.githubusercontent.com/orionmc/SoftEng0/main/heart.ds.csv')
#      18 heartds0 = pd.read_csv(r'C:\Users\user0\Documents\BPP\Software Engineering\Git\0\SoftEng0\SoftEng0\heart.ds.csv')
#
# File c:\Program Files\Python311\Lib\site-packages\pycaret\classification\__init__.py:1
# ----> 1 from pycaret.classification.functional import (
#       2     add_metric,
#       3     automl,
#       4     blend_models,
#       5     calibrate_model,
#       6     check_drift,
#       7     check_fairness,
#       8     compare_models,
#       9     convert_model,
#      10     create_api,
#      11     create_app,
#      12     create_docker,
#      13     create_model,
#      14     dashboard,
#      15     deploy_model,
#      16     ensemble_model,
#      17     evaluate_model,
#      18     finalize_model,
#      19     get_allowed_engines,
#      20     get_config,
#      21     get_current_experiment,
#      22     get_engine,
#      23     get_leaderboard,
#      24     get_logs,
#      25     get_metrics,
#      26     interpret_model,
#      27     load_experiment,
#      28     load_model,
#      29     models,
#      30     optimize_threshold,
#      31     plot_model,
#      32     predict_model,
#      33     pull,
#      34     remove_metric,
#      35     save_experiment,
#      36     save_model,
#      37     set_config,
#      38     set_current_experiment,
#      39     setup,
#      40     stack_models,
#      41     tune_model,
#      42 )
#      43 from pycaret.classification.oop import ClassificationExperiment
#      45 __all__ = [
#      46     "ClassificationExperiment",
#      47     "setup",
#    (...)
#      86     "check_drift",
#      87 ]
#
# File c:\Program Files\Python311\Lib\site-packages\pycaret\classification\functional.py:8
#       5 import pandas as pd
#       6 from joblib.memory import Memory
# ----> 8 from pycaret.classification.oop import ClassificationExperiment
#       9 from pycaret.internal.parallel.parallel_backend import ParallelBackend
#      10 from pycaret.loggers.base_logger import BaseLogger
#
# File c:\Program Files\Python311\Lib\site-packages\pycaret\classification\oop.py:31
#      29 from pycaret.internal.pipeline import Pipeline as InternalPipeline
#      30 from pycaret.internal.preprocess.preprocessor import Preprocessor
# ---> 31 from pycaret.internal.pycaret_experiment.non_ts_supervised_experiment import (
#      32     _NonTSSupervisedExperiment,
#      33 )
#      34 from pycaret.internal.validation import is_sklearn_cv_generator
#      35 from pycaret.loggers.base_logger import BaseLogger
#
# File c:\Program Files\Python311\Lib\site-packages\pycaret\internal\pycaret_experiment\non_ts_supervised_experiment.py:3
#       1 import pandas as pd
# ----> 3 from pycaret.internal.pycaret_experiment.supervised_experiment import (
#       4     _SupervisedExperiment,
#       5 )
#       8 class _NonTSSupervisedExperiment(_SupervisedExperiment):
#       9     def __init__(self) -> None:
#
# File c:\Program Files\Python311\Lib\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py:57
#      50 from pycaret.internal.patches.sklearn import fit_and_score as fs
#      51 from pycaret.internal.pipeline import (
#      52     Pipeline,
#      53     estimator_pipeline,
#      54     get_pipeline_estimator_label,
#      55     get_pipeline_fit_kwargs,
#      56 )
# ---> 57 from pycaret.internal.pycaret_experiment.tabular_experiment import _TabularExperiment
#      58 from pycaret.internal.tunable import TunableMixin
#      59 from pycaret.internal.validation import is_fitted, is_sklearn_cv_generator
#
# File c:\Program Files\Python311\Lib\site-packages\pycaret\internal\pycaret_experiment\tabular_experiment.py:14
#      12 import pandas as pd
#      13 import plotly.express as px  # type: ignore
# ---> 14 import scikitplot as skplt  # type: ignore
#      15 from IPython.display import display as ipython_display
#      16 from joblib.memory import Memory
#
# File c:\Program Files\Python311\Lib\site-packages\scikitplot\__init__.py:2
#       1 from __future__ import absolute_import, division, print_function, unicode_literals
# ----> 2 from . import metrics, cluster, decomposition, estimators
#       3 __version__ = '0.3.7'
#       6 from scikitplot.classifiers import classifier_factory
#
# File c:\Program Files\Python311\Lib\site-packages\scikitplot\metrics.py:27
#      24 from sklearn.calibration import calibration_curve
#      25 from sklearn.utils import deprecated
# ---> 27 from scipy import interp
#      29 from scikitplot.helpers import binary_ks_curve, validate_labels
#      30 from scikitplot.helpers import cumulative_gain_curve
#
# ImportError: cannot import name 'interp' from 'scipy' (c:\Program Files\Python311\Lib\site-packages\scipy\__init__.py)
